# %% [markdown]
# <img src='üni.png'>

# %% [markdown]
# # Öğrenci Notu Tahmin Etme Modeli

# %% [markdown]
# ### Regression AutoMl ile çözeceğiz

# %%
#pip install pycaret

# %%
import pandas as pd

# %%
#Regression AutoMl

# %%
from pycaret.regression import*

# %%
df=pd.read_csv('Student_Marks.csv')

# %%
df.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['number_courses'].plot(kind='hist', bins=20, title='number_courses')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['time_study'].plot(kind='hist', bins=20, title='time_study')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Marks'].plot(kind='hist', bins=20, title='Marks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
# ...

# %%
setup(data=df,target='Marks')
# Out:
# <style type="text/css">
# #T_26ccf_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_26ccf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26ccf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_26ccf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26ccf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26ccf_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_26ccf_row0_col1" class="data row0 col1" >2163</td>
#     </tr>
#     <tr>
#       <th id="T_26ccf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26ccf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_26ccf_row1_col1" class="data row1 col1" >Marks</td>
#     </tr>
#     <tr>
#       <th id="T_26ccf_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_b808e th {
#   text-align: left;
# }
# ...

# %%
# Yukaridaki tabloya göre en iyi tahmini veren model  Extra Trees Regressor- % 0.9936 oranında doğru tahmin ediyor
# Hata MSE  0.6621.

# %%
# Aynı poblemi LinearRegression kullanarak da çözmek istersek

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.tree import ExtraTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
lr=LinearRegression()

# %%
x=df[['number_courses','time_study']]
y=df[['Marks']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
model=lr.fit(x_train,y_train)

# %%
tahmin=model.predict(x_test)

# %%
r2_score(tahmin,y_test)
# Out:
# 0.9219617777759718

# %%
(mean_squared_error(tahmin,y_test))**0.5
# Out:
# 3.7683850833446595

# %%
# Corr ve tabloda göstermek istersek

# %%
df.describe()
# Out:
#        number_courses  time_study       Marks
# count      100.000000  100.000000  100.000000
# mean         5.290000    4.077140   24.417690
# std          1.799523    2.372914   14.326199
# min          3.000000    0.096000    5.609000
# 25%          4.000000    2.058500   12.633000
# 50%          5.000000    4.022000   20.059500
# 75%          7.000000    6.179250   36.676250
# max          8.000000    7.957000   55.299000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
figure=plt.scatter(x=df["time_study"],y=df["Marks"])

# %%
sns.pairplot(df,hue='Marks')
